# %% [markdown]
# Importing color image

# %%
import cv2

# %%
img_1 = cv2.imread('/content/TIME.jpg')

# %%
print(img.shape)
# Out:
# (183, 275, 3)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img_1)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %% [markdown]
# Importing grey scale image

# %%
img_2 = cv2.imread('/content/TIME.jpg',0)

# %%
cv2_imshow(img_2)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
print(img_2.shape)
# Out:
# (183, 275)

# %% [markdown]
# Saving image

# %%
cv2.imwrite('output.jpg',img_2)
# Out:
# True

# %% [markdown]
# Resizing the image height and width

# %%
new_img = cv2.resize(img_1,(100,150))

# %%
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x150>

# %%
print(new_img.shape)
# Out:
# (150, 100, 3)

# %% [markdown]
# Bluring image

# %%
blur_img = cv2.blur(img_1,(500,50))
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
print(blur_img)
# Out:
# [[[ 45  42  23]
#   [ 45  42  23]
#   [ 45  42  23]
#   ...
#   [ 45  41  22]
#   [ 45  41  22]
#   [ 45  41  22]]
#
#  [[ 45  42  23]
#   [ 45  42  23]
#   [ 45  42  23]
#   ...
#   [ 45  41  22]
#   [ 45  41  22]
#   [ 45  41  22]]
#
#  [[ 45  42  23]
#   [ 45  42  23]
#   [ 45  42  23]
#   ...
#   [ 45  41  22]
#   [ 45  41  22]
#   [ 45  41  22]]
#
#  ...
#
#  [[110 121 153]
#   [110 121 153]
#   [110 121 153]
#   ...
#   [109 120 151]
#   [109 120 151]
#   [109 120 151]]
#
#  [[110 121 153]
#   [110 121 153]
#   [110 121 153]
#   ...
#   [109 120 151]
#   [109 120 151]
#   [109 120 151]]
#
#  [[110 121 153]
#   [110 121 153]
#   [110 121 153]
#   ...
#   [109 120 151]
#   [109 120 151]
#   [109 120 151]]]

# %%
print(img_1)
# Out:
# [[[ 47  43  24]
#   [ 47  43  24]
#   [ 47  43  24]
#   ...
#   [ 42  38  14]
#   [ 42  38  14]
#   [ 42  38  14]]
#
#  [[ 47  43  24]
#   [ 47  43  24]
#   [ 47  43  24]
#   ...
#   [ 42  38  14]
#   [ 42  38  14]
#   [ 42  38  14]]
#
#  [[ 47  43  24]
#   [ 47  43  24]
#   [ 47  43  24]
#   ...
#   [ 42  38  14]
#   [ 42  38  14]
#   [ 42  38  14]]
#
#  ...
#
#  [[ 94  93  95]
#   [ 91  90  92]
#   [ 87  86  88]
#   ...
#   [100 113 139]
#   [ 94 107 129]
#   [ 88  98 122]]
#
#  [[ 98  99  97]
#   [ 95  96  94]
#   [ 89  90  88]
#   ...
#   [116 130 158]
#   [111 124 150]
#   [103 116 142]]
#
#  [[103 104 100]
#   [ 99 100  96]
#   [ 93  94  90]
#   ...
#   [122 140 171]
#   [119 133 161]
#   [110 124 152]]]
